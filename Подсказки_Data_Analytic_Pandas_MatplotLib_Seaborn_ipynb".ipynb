# %% [markdown]
# <a href="https://colab.research.google.com/github/airesult/base/blob/master/%D0%9F%D0%BE%D0%B4%D1%81%D0%BA%D0%B0%D0%B7%D0%BA%D0%B8_Data_Analytic_Pandas_MatplotLib_Seaborn_ipynb%22.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Подключение библиотек
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Вызов датасета по id google
! gdown --id 1zRa2yGQfd_ZzpYW4TiePXjMWwxq5QhrB
# Out:
# /usr/local/lib/python3.10/dist-packages/gdown/cli.py:121: FutureWarning: Option `--id` was deprecated in version 4.3.1 and will be removed in 5.0. You don't need to pass it anymore to use a file ID.
#   warnings.warn(
# Downloading...
# From: https://drive.google.com/uc?id=1zRa2yGQfd_ZzpYW4TiePXjMWwxq5QhrB
# To: /content/contr__.csv
# 100% 199k/199k [00:00<00:00, 48.6MB/s]

# %%
# Подключение к Pandas
df = pd.read_csv('/content/contr__.csv')

# %%
# Количество анкет
len(df)
# Out:
# 286

# %%
# Основные данные
df.head()
# Out:
#       VUZ      Marrid  AGE_M     DaysM          LC  Cours  Возраст  \
# 0  ЗабИЖТ  Не замужем     12  3-6 дней  20-35 дней      4       21
# 1  СПбГУТ  Не замужем     14  3-6 дней  20-35 дней      4       21
# 2  ЗабИЖТ  Не замужем     12  3-6 дней  20-35 дней      4       21
# 3  СПбГУТ     Замужем     13  3-6 дней  20-35 дней      4       21
# 4  СПбГУТ  Не замужем     14  3-6 дней  20-35 дней      4       22
#
#                                                Dif_M              Pr_M  \
# 0  ощущение тяжести внизу живота, запор/диарея, б...  каждые 3-5 часов
# 1        ощущение тяжести внизу живота, запор/диарея  каждые 3-5 часов
# 2                                          жалоб нет  каждые 3-5 часов
# 3  ощущение тяжести внизу живота, высыпания, боль...          2-3 часа
# 4                                          жалоб нет          2-3 часа
#
#                  C_M  ...    How_B Birth Z_Birth    How_A              How_G  \
# ...

# %%
# Группировка колонок со средним значением
df.groupby(['Возраст','VUZ']).mean()
# Out:
# <ipython-input-11-c98e84c2ce3b>:2: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby(['Возраст','VUZ']).mean()
#                                         AGE_M     Cours  Birth
# Возраст VUZ
# 17      СПбГПМУ                          12.4  1.000000    NaN
#         СПбГТИ(ТУ)                       11.0  1.000000    NaN
# 18      ЗабГУ                            13.0  1.666667    NaN
#         СЗИУ РАНХиГС                     12.0  1.000000    NaN
#         СПБТОТФиП                        12.0  3.000000    NaN
# ...                                       ...       ...    ...
# 25      ТГПУ                             11.0  1.000000    1.0
#         УрФУ                             10.0  5.000000    NaN
# 26      СПбГПМУ                          14.0  6.000000    NaN
# ...

# %%
salary = pd.Series([30,30,40,60,50])
salary.mean() # 42.0

salary.sort_values() # Сортировка
salary.median() # Середина числового ряда


df['Age'].mean() # Среднее значение  / 20.48
df['Age'].min()  # Минимальное       / 17
df['Age'].max()  # Максимальное      / 39
df['Age'].median() # Середина числового ряда / 21.0

df['Age'].agg(['median','mean','max','min'])
# median    21.000000
# mean      20.482517
# max       39.000000
# min       17.000000

(df['Age'] <= 20).mean() # Условия


df['Age'].quantile(0.1)  # Кватниль: У 10% меньше 18 лет
df['Age'].quantile(0.25) # Квартиль: У 25% меньше 19 лет
df['Age'].quantile(0.5) # Квартиль: У 5% меньше 21 год
df['Age'].quantile(0.75) # Квартиль: У 75% меньше 21 год


df['Age'].rank(pct=True).head() #Score

df['Age'].describe()
# count    286.000000
# mean      20.482517
# std        2.174342
# min       17.000000
# 25%       19.000000
# 50%       21.000000
# 75%       21.000000
# max       39.000000


# Пропуски в процентах + сортировка
df.isna().mean().sort_values(ascending=False)

# Вывод всех параметров
df['VUZ'].value_counts(dropna=False)


# По количеству
df['Age'].value_counts()


# В процентах (Доля * 100)
df['Age'].value_counts(normalize=True)


df['Age'].agg(['median','mean'])


# Способ разбиения по частям
df['AGE_TEST:'] = pd.cut(df['Age'], 15)
df.groupby('AGE_TEST:')['Age'].count()


# Гистограмма
df['Age'].hist()


# Кореляция
df[['Age', 'VUZ']].corr()

# Использование точечного скаттера (45 гр)
df.plot(rot=45, x='Age', y='VUZ', kind='scatter', alpha=0.2)



# Замена имени колонок
df.rename(columns={'Age' : 'Возраст'})
df.rename(columns={'Age' : 'Возраст'}, inplace=True) # True - значит не отображает


######### PIE ############

# Использование паев
df['VUZ'].value_counts(dropna=False).plot.pie(ylabel='ВУЗы', y='VUZ', autopct='%1.0f%%', pctdistance=1.25, labeldistance=.6)

# Использование паев c тенью
df['VUZ'].value_counts(dropna=False).plot.pie(ylabel='ВУЗы', autopct='%1.0f%%', shadow=True, startangle=90)

# Использование паев c уменьшением радиуса
df['VUZ'].value_counts(dropna=False).plot.pie(ylabel='ВУЗы', autopct='%1.0f%%', shadow=True, startangle=90, textprops={'size': 'smaller'}, radius=0.5)



#########

fig, ax = plt.subplots()

ax.pie(sizes, labels=labels, autopct='%.0f%%',
       textprops={'size': 'smaller'}, radius=0.5)
plt.show()

#########




########## SEABORN ############

# Линейная
sns.lineplot(data=df, x="Age", y="VUZ")

sns.barplot(x="country", y="beer_servings", data=drinks_df)


#########


df['VUZ'].value_counts().iloc[:100].plot(kind='bar')
plt.title("Возраст")
plt.show()


df.groupby('Family')['Family'].count().plot()
plt.xlabel('Семья')
plt.ylabel('Курс')
plt.show()



#########

df.groupby('VUZ')['Cours'].mean().plot(kind='bar', label='ВУЗ')
df.groupby('VUZ')['Cours'].mean().plot(kind='bar', label='ВУЗы')

plt.xlabel('ВУЗ')
plt.ylabel('Возраст')
plt.legend()
plt.show()

#########
